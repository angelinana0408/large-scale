# %%
import numpy as np
from time import time
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import NullFormatter
from sklearn.manifold import TSNE
import matplotlib.backends.backend_pdf
from sklearn.decomposition import TruncatedSVD
from sklearn.random_projection import sparse_random_matrix

def load_file(file_name):
    
    npArray = np.load(file_name)
    
    return npArray

def assignGroupID(npDataSet):
    
    groupID = np.zeros(npDataSet.shape[0],dtype=np.int)
    
    for dataIndex in range(npDataSet.shape[0]):
        for groupIndex in range(npDataSet.shape[1]):
            if(npDataSet[dataIndex][groupIndex] == 1):
                groupID[dataIndex]=groupIndex
    return groupID

def tsne(npEmbeddingData):
    npTsne_embedding = TSNE(n_components=2, perplexity=40,verbose=0,n_iter_without_progress=500, init='pca').fit_transform(npEmbeddingData)
    return npTsne_embedding

def PCA(npEmbeddingData):
    npTsne_embedding = TSNE(n_components=2, perplexity=40,verbose=0,n_iter_without_progress=500, init='pca').fit_transform(npEmbeddingData)
    return npTsne_embedding

def TruncatedSVD(npEmbeddingData):
    svd = TruncatedSVD(n_iter=7, random_state=42)
    npTsne_embedding = svd.fit(npEmbeddingData) 
    return npTsne_embedding

def drawGraph(npTsne_embedding,groupID,graphName):
    
    style = ['bo', 'go', 'ro', 'co', 'mo', 'yo', 'ko']

    for tsneIndex in range(npTsne_embedding.shape[0]): 
        gourpIndex = groupID[tsneIndex]
        if gourpIndex == 0: 
            G1, = plt.plot(npTsne_embedding[tsneIndex][0],npTsne_embedding[tsneIndex][1],style[gourpIndex],label=str(gourpIndex+1))                
        if gourpIndex == 1: 
            G2, = plt.plot(npTsne_embedding[tsneIndex][0],npTsne_embedding[tsneIndex][1],style[gourpIndex],label=str(gourpIndex+1))     
        if gourpIndex == 2: 
            G3, = plt.plot(npTsne_embedding[tsneIndex][0],npTsne_embedding[tsneIndex][1],style[gourpIndex],label=str(gourpIndex+1))          
        if gourpIndex == 3: 
            G4, = plt.plot(npTsne_embedding[tsneIndex][0],npTsne_embedding[tsneIndex][1],style[gourpIndex],label=str(gourpIndex+1))              
        if gourpIndex == 4: 
            G5, = plt.plot(npTsne_embedding[tsneIndex][0],npTsne_embedding[tsneIndex][1],style[gourpIndex],label=str(gourpIndex+1))     
        if gourpIndex == 5: 
            G6, = plt.plot(npTsne_embedding[tsneIndex][0],npTsne_embedding[tsneIndex][1],style[gourpIndex],label=str(gourpIndex+1))              
        if gourpIndex == 6:  
            G7, = plt.plot(npTsne_embedding[tsneIndex][0],npTsne_embedding[tsneIndex][1],style[gourpIndex],label=str(gourpIndex+1)) 
    
    '''
    style = []
    for l in groupID:
        if l == 0:
            style.append('bo')
        if l == 1:
            style.append('go')
        if l == 2:
            style.append('ro')
        if l == 3:
            style.append('co')
        if l == 4:
            style.append('mo')
        if l == 5:
            style.append('yo')
        if l == 6:
            style.append('ko')
            
    plt.scatter(npTsne_embedding[:,0], npTsne_embedding[:,1], style=style)
    '''
    plt.title(graphName)
    #plt.savefig(graphName+"_"+"test"+str(graphID)+".png")
    #plt.legend([G1, G2, G3, G4, G5, G6, G7], ['1', '2', '3', '4', '5', '6', '7'])
    
    plt.show()
    
def sortLabel(npEmbeddingData, groupID, npDataSet):
    groupMemberNum = []
    for i in range(npDataSet.shape[1]):
        groupMemberNum.append(0)
    EmbeddingData_sorted = []
    for i in groupID:
        groupMemberNum[i] += 1
    for j in range(0,7):
        maxGroupID = groupMemberNum.index(max(groupMemberNum))
        for dataIndex in range(len(groupID)):
            if groupID[dataIndex] == maxGroupID:
                EmbeddingData_sorted.append(npDataSet[dataIndex])
        groupMemberNum[maxGroupID] = -1
    return npEmbeddingData_sorted
        
#test GCN
graphName = "GCN"
doc_name = "cora/cora_labels.npy"
npDataSet = load_file(doc_name)
groupID = assignGroupID(npDataSet)
embedding_file = "cora/gcn_cora_emb_295.npy"
npEmbeddingData = load_file(embedding_file)
print(npEmbeddingData.shape[1])
#npEmbeddingData_sorted = sortLabel(npEmbeddingData, groupID,npDataSet)
#npTsne_embedding = tsne(npEmbeddingData)
npTsne_embedding = TruncatedSVD(npEmbeddingData)
drawGraph(npTsne_embedding,groupID,graphName)

graphName = "node2vec" 
embedding_file = "cora/cora_emb_iter_1_p_1_q_1_walk_40_win_10.npy"
npEmbeddingData = load_file(embedding_file)
print(npEmbeddingData.shape[1])
#npTsne_embedding = tsne(npEmbeddingData)
#drawGraph(npTsne_embedding,groupID,graphName)
# Out:
# 200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6d93dac02e7a> in <module>()
#     110 #npEmbeddingData_sorted = sortLabel(npEmbeddingData, groupID,npDataSet)
#     111 #npTsne_embedding = tsne(npEmbeddingData)
# --> 112 npTsne_embedding = TruncatedSVD(npEmbeddingData)
#     113 drawGraph(npTsne_embedding,groupID,graphName)
#     114
#
# <ipython-input-6-6d93dac02e7a> in TruncatedSVD(npEmbeddingData)
#      34
#      35 def TruncatedSVD(npEmbeddingData):
# ---> 36     svd = TruncatedSVD(n_iter=7, random_state=42)
#      37     npTsne_embedding = svd.fit(npEmbeddingData)
#      38     return npTsne_embedding
#
# TypeError: TruncatedSVD() got an unexpected keyword argument 'n_iter'
